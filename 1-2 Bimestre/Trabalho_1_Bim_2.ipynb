# %% [markdown]
# ##1o Trabalho 2o Bimestre
#
# Nome: Paulo Moisés Gonçalves Vieira
# R.A: 159047-23

# %% [markdown]
# 1. Crie um dicionário com 6 elementos.

# %%
frutas = {
    "banana":25,
    "maca":47,
    "pera":99,
    "uva":549,
    "abacaxi":6984,
    "melancia":1988
}

frutas
# Out:
# {'banana': 25,
#  'maca': 47,
#  'pera': 99,
#  'uva': 549,
#  'abacaxi': 6984,
#  'melancia': 1988}

# %% [markdown]
# 2. Crie um dicionario com 5 elementos numerico e 5 strings.

# %%
nomeUser = {
    'paulo':1,
    'joao':2,
    'eduardo':3,
    'vitor':4,
    'felipe':5,
    'lucas':6
}
nomeUser
# Out:
# {'paulo': 1, 'joao': 2, 'eduardo': 3, 'vitor': 4, 'felipe': 5, 'lucas': 6}

# %% [markdown]
# 3. Traga somente as chaves do dicionario do exercicio anterior.

# %%
nomeUser.keys()
# Out:
# dict_keys(['paulo', 'joao', 'eduardo', 'vitor', 'felipe', 'lucas'])

# %% [markdown]
# 4. Traga somente os valores do dicionario do exercicio anterior(exer:2)

# %%
nomeUser.values()
# Out:
# dict_values([1, 2, 3, 4, 5, 6])

# %% [markdown]
# 5. Crie um dicionario com uma lista dentro.

# %%
dicionario = {
    "carro": ['porsche', 'bmw'],
    "moto": ['honda', 'yamaha']
}
dicionario
# Out:
# {'carro': ['porsche', 'bmw'], 'moto': ['honda', 'yamaha']}

# %% [markdown]
# 6. A partir do dicionario do exercicio anterior faça adcione uma string com nome de uma pessoa e uma idade.

# %%
dicionario.update({'nome':'paulo', 'idade': 18})
dicionario
# Out:
# {'carro': ['porsche', 'bmw'],
#  'moto': ['honda', 'yamaha'],
#  'nome': 'paulo',
#  'idade': 18}

# %% [markdown]
# 7. Escolha um elemento do exercicio 2 e faça um delete.

# %%
dicionario.pop("moto")
dicionario
# Out:
# {'carro': ['porsche', 'bmw'], 'nome': 'paulo', 'idade': 18}

# %% [markdown]
# 8. Crie uma tupla com 10 elemente, entre string e numerais.

# %%
tupla = ('brasil', 7, 1, 'alemanha', 4, 'colombia',1980, 'paraguai', 1789, 'uruguai', )

# %% [markdown]
# 9. Crie uma interpolação, escolha uma do seu gosto.

# %%
nome = 'Paulo'
nacionalidade = 'brasileiro'

print(f"Olá, meu nome é {nome} e sou {nacionalidade}.")
# Out:
# Olá, meu nome é Paulo e sou brasileiro.

# %% [markdown]
# 10. Mostre o tamanho do dicionario do exercicio 1.

# %%
len(frutas)
# Out:
# 6

# %% [markdown]
# 11. Mostre apenas as chaves do dicionário do exercicio 1.

# %%
frutas.keys()
# Out:
# dict_keys(['banana', 'maca', 'pera', 'uva', 'abacaxi', 'melancia'])

# %% [markdown]
# 12. Delete apenas um elemento do dicionario do exercicio 1

# %%
del frutas['pera']
print(frutas)
# Out:
# {'banana': 25, 'maca': 47, 'uva': 549, 'abacaxi': 6984, 'melancia': 1988}
