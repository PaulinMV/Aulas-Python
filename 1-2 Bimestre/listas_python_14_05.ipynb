# %% [markdown]
# Listas

# %%
#Criando e vendo qual tipo da variavel
lista = []
type (lista)
# Out:
# list

# %%
print(lista)
# Out:
# []

# %%
#Funçao APPEND
lista.append(1)
lista.append(2)
print(lista)
# Out:
# [1, 2]

# %%
#Criando uma lista
lista_ingredientes = ['macarrao',
                      'alho',
                      'bacon',
                      'queijo']
print(lista_ingredientes)
# Out:
# ['macarrao', 'alho', 'bacon', 'queijo']

# %%
#Criando uma lista com strings e numeros
lista_2 = [2340, 3452, 'str1', 'str2']
print(lista_2)
# Out:
# [2340, 3452, 'str1', 'str2']

# %%
#Removendo conteudo de uma lista
lista_2.remove(3452)
print(lista_2)
# Out:
# [2340, 'str1', 'str2']

# %%
#Mudando a ordem da lista de uma lista com REVERSE
lista_2.reverse()
print(lista_2)
# Out:
# ['str2', 'str1', 2340]
