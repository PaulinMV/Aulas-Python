# %% [markdown]
# # <font color= 'green'>Python de A a Z </font>
# # <font color= 'blue'> 1. Trabalhando com o Google Colab & Testando a linguagem. </font>

# %%
#Teste de Saída
#Isso é um comentario, feito por '#'
print('Hello World')
# Out:
# Hello World

# %%
#Teste de Calculo
2 + 2
# Out:
# 4

# %%
#Teste Type - Verifica qual o tipo
x = 'teste'
y = 2
z = 2.5
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#Retorno de valor ABSoluto
abs(-225)
# Out:
# 225
